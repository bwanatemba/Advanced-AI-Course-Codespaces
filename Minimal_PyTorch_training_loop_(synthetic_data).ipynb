# %% [markdown]
# <a href="https://colab.research.google.com/github/bwanatemba/Advanced-AI-Course-Codespaces/blob/main/Minimal_PyTorch_training_loop_(synthetic_data).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
import torch.nn as nn

torch.manual_seed(0)
X = torch.randn(256, 10)
y = (X.sum(1) > 0).long()  # binary labels

model = nn.Sequential(nn.Linear(10, 32), nn.ReLU(), nn.Linear(32, 2))
opt = torch.optim.Adam(model.parameters(), lr=1e-2)
loss_fn = nn.CrossEntropyLoss()

for epoch in range(10):
    opt.zero_grad()
    loss = loss_fn(model(X), y)
    loss.backward()
    opt.step()
    print(f"epoch={epoch:02d} loss={loss.item():.4f}")
# Out:
# epoch=00 loss=0.6336
# epoch=01 loss=0.6000
# epoch=02 loss=0.5666
# epoch=03 loss=0.5330
# epoch=04 loss=0.4989
# epoch=05 loss=0.4644
# epoch=06 loss=0.4302
# epoch=07 loss=0.3966
# epoch=08 loss=0.3643
# epoch=09 loss=0.3335
